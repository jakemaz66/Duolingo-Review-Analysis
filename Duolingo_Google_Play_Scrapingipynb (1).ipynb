# %% [markdown]
# ## Importing and Downloading Necessary Libraries

# %%
# !pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.4

# %%
import pandas as pd

from google_play_scraper import app, Sort, reviews

from pprint import pprint

import datetime as dt
from tzlocal import get_localzone

import random
import time

# %% [markdown]
# ## Defining App

# %%
app_name = 'Duolingo'
app_id = 'com.duolingo&hl=en'

# %%
app_info = []

info = app(app_id)
del info['comments']
app_info.append(info)


pprint(app_info)
# Out:
# [{'adSupported': True,
#   'appId': 'com.duolingo&hl=en',
#   'categories': [{'id': 'EDUCATION', 'name': 'Education'}],
#   'containsAds': True,
#   'contentRating': 'Everyone',
#   'contentRatingDescription': None,
#   'currency': 'USD',
#   'description': 'Learn a new language with the world’s most-downloaded '
#                  'education app! Duolingo is the fun, free app for learning '
#                  '40+ languages through quick, bite-sized lessons. Practice '
#                  'speaking, reading, listening, and writing to build your '
#                  'vocabulary and grammar skills.\r\n'
#                  '\r\n'
#                  'Designed by language experts and loved by hundreds of '
#                  'millions of learners worldwide, Duolingo helps you prepare '
#                  'for real conversations in Spanish, French, Chinese, Italian, '
#                  'German, English, and more.\r\n'
#                  '\r\n'
#                  'Whether you’re learning a language for travel, school, '
#                  'career, family and friends, or your brain health, you’ll '
#                  'love learning with Duolingo. \r\n'
#                  '\r\n'
#                  'Why Duolingo?\r\n'
#                  '\r\n'
#                  '• Duolingo is fun and effective. Game-like lessons and fun '
#                  'characters help you build solid speaking, reading, '
#                  'listening, and writing skills.\r\n'
#                  '\r\n'
#                  '• Duolingo works. Designed by language experts, Duolingo has '
#                  'a science-based teaching methodology proven to foster '
#                  'long-term language retention.\r\n'
#                  '\r\n'
#                  '• Track your progress. Work toward your language learning '
#                  'goals with playful rewards and achievements when you make '
#                  'practicing a daily habit!\r\n'
#                  '\r\n'
#                  '• Join 300+ million learners. Stay motivated with '
#                  'competitive Leaderboards as you learn alongside our global '
#                  'community. \r\n'
#                  '\r\n'
#                  '• Every language course is free. Learn Spanish, French, '
#                  'German, Italian, Russian, Portuguese, Turkish, Dutch, Irish, '
#                  'Danish, Swedish, Ukrainian, Esperanto, Polish, Greek, '
#                  'Hungarian, Norwegian, Hebrew, Welsh, Arabic, Latin, '
#                  'Hawaiian, Scottish Gaelic, Vietnamese, Korean, Japanese, '
#                  'English, and even High Valyrian!\r\n'
#                  '\r\n'
#                  'What the world is saying about Duolingo⭐️⭐️⭐️⭐️⭐️:\r\n'
#                  '\r\n'
#                  'Editor\'s Choice and "Best of the Best” —Google Play\r\n'
#                  '\r\n'
#                  '“Far and away the best language-learning app.” —The Wall '
#                  'Street Journal\r\n'
#                  '\r\n'
#                  '“This free app and website is among the most effective '
#                  'language-learning methods I’ve tried… lessons come in the '
#                  'form of brief challenges — speaking, translating, answering '
#                  'multiple-choice questions — that keep me coming back for '
#                  'more.” —The New York Times\r\n'
#                  '\r\n'
#                  '“Duolingo may hold the secret to the future of education.” — '
#                  'TIME Magazine\r\n'
#                  '\r\n'
#                  '“...Duolingo is cheerful, lighthearted and fun…” — Forbes\r\n'
#                  '\r\n'
#                  'If you like Duolingo, try Super Duolingo for 14 days free! '
#                  'Learn a language fast with no ads, and get fun perks like '
#                  'Unlimited Hearts and Monthly Streak Repair. \r\n'
#                  '\r\n'
#                  'Send any feedback to android@duolingo.com\r\n'
#                  '\r\n'
#                  'Use Duolingo on the Web at https://www.duolingo.com\r\n'
#                  '\r\n'
#                  'Privacy Policy: https://www.duolingo.com/privacy',
#   'descriptionHTML': 'Learn a new language with the world’s most-downloaded '
#                      'education app! Duolingo is the fun, free app for '
#                      'learning 40+ languages through quick, bite-sized '
#                      'lessons. Practice speaking, reading, listening, and '
#                      'writing to build your vocabulary and grammar '
#                      'skills.<br><br>Designed by language experts and loved by '
#                      'hundreds of millions of learners worldwide, Duolingo '
#                      'helps you prepare for real conversations in Spanish, '
#                      'French, Chinese, Italian, German, English, and '
#                      'more.<br><br>Whether you’re learning a language for '
#                      'travel, school, career, family and friends, or your '
#                      'brain health, you’ll love learning with Duolingo. '
#                      '<br><br>Why Duolingo?<br><br>• Duolingo is fun and '
#                      'effective. Game-like lessons and fun characters help you '
#                      'build solid speaking, reading, listening, and writing '
#                      'skills.<br><br>• Duolingo works. Designed by language '
#                      'experts, Duolingo has a science-based teaching '
#                      'methodology proven to foster long-term language '
#                      'retention.<br><br>• Track your progress. Work toward '
#                      'your language learning goals with playful rewards and '
#                      'achievements when you make practicing a daily '
#                      'habit!<br><br>• Join 300+ million learners. Stay '
#                      'motivated with competitive Leaderboards as you learn '
#                      'alongside our global community. <br><br>• Every language '
#                      'course is free. Learn Spanish, French, German, Italian, '
#                      'Russian, Portuguese, Turkish, Dutch, Irish, Danish, '
#                      'Swedish, Ukrainian, Esperanto, Polish, Greek, Hungarian, '
#                      'Norwegian, Hebrew, Welsh, Arabic, Latin, Hawaiian, '
#                      'Scottish Gaelic, Vietnamese, Korean, Japanese, English, '
#                      'and even High Valyrian!<br><br>What the world is saying '
#                      'about Duolingo⭐️⭐️⭐️⭐️⭐️:<br><br>Editor&#39;s Choice and '
#                      '&quot;Best of the Best” —Google Play<br><br>“Far and '
#                      'away the best language-learning app.” —The Wall Street '
#                      'Journal<br><br>“This free app and website is among the '
#                      'most effective language-learning methods I’ve tried… '
#                      'lessons come in the form of brief challenges — speaking, '
#                      'translating, answering multiple-choice questions — that '
#                      'keep me coming back for more.” —The New York '
#                      'Times<br><br>“Duolingo may hold the secret to the future '
#                      'of education.” — TIME Magazine<br><br>“...Duolingo is '
#                      'cheerful, lighthearted and fun…” — Forbes<br><br>If you '
#                      'like Duolingo, try Super Duolingo for 14 days free! '
#                      'Learn a language fast with no ads, and get fun perks '
#                      'like Unlimited Hearts and Monthly Streak Repair. '
#                      '<br><br>Send any feedback to '
#                      'android@duolingo.com<br><br>Use Duolingo on the Web at '
#                      'https://www.duolingo.com<br><br>Privacy Policy: '
#                      'https://www.duolingo.com/privacy',
#   'developer': 'Duolingo',
#   'developerAddress': 'Duolingo\n5900 Penn Avenue\nPittsburgh PA 15206',
#   'developerEmail': 'android@duolingo.com',
#   'developerId': '6957685454452609502',
#   'developerWebsite': 'https://www.duolingo.com/',
#   'free': True,
#   'genre': 'Education',
#   'genreId': 'EDUCATION',
#   'headerImage': 'https://play-lh.googleusercontent.com/7zm7XXTJiYTCdoAXF6NcwUJ8asRTwNK_O08bTC6QBInFDAqAczKI9DmN7TrY2Id5HA',
#   'histogram': [428942, 228035, 518358, 2338730, 13488475],
#   'icon': 'https://play-lh.googleusercontent.com/hSyebBlYwtE2aMjzSIHasUO9cQv9HgNAw9owy6ADO0szOKYO3rDk60r7jcyXu82Fbq1M',
#   'inAppProductPrice': '$0.99 - $149.99 per item',
#   'installs': '100,000,000+',
#   'minInstalls': 100000000,
#   'offersIAP': True,
#   'originalPrice': None,
#   'price': 0,
#   'privacyPolicy': 'https://www.duolingo.com/privacy',
#   'ratings': 17002572,
#   'realInstalls': 457279926,
#   'released': 'May 29, 2013',
#   'reviews': 697996,
#   'sale': False,
#   'saleText': None,
#   'saleTime': None,
#   'score': 4.6603236,
#   'screenshots': ['https://play-lh.googleusercontent.com/_lHrG9oyf9pviJWH-5F7EWJ0U2TTn8BncMdROrF8S0SQNiMWDP4OK-_op361D2ax9mSu',
#                   'https://play-lh.googleusercontent.com/eZqTnAiCGJaWm0BFsjCi8YmF5RZ8QWLRJYbjrz2T2kOle7x8aDmn-A_RwYi43srOLI0',
#                   'https://play-lh.googleusercontent.com/rBQyakUWhCsUwNLDce6u6z-F1AE_jzXxdz5oauCJ1NNQiZf1G8cktVlUd6UUGuS9KzUc',
#                   'https://play-lh.googleusercontent.com/qLpS0qqQmE0c3K6KaJaTQ7NNdEr29H6_gj-4L84TP-BpTvbYKj7kFca_P0lWINWyTWs',
#                   'https://play-lh.googleusercontent.com/S-E0-JkuvLXgplIspLqAP1AWsnmVbpowKwJLqUx50rHfSFXtnSQtvhhN2nqyD1j2Xpo',
#                   'https://play-lh.googleusercontent.com/omXNNtzhzoTtgEZE1nlGezCvQRq6eBF0zFILc812FKuAWfs_rHSoXL8EFnguwU8sYe0'],
#   'summary': 'Learn Spanish, French, German, Italian, English and more '
#              'languages for free.',
#   'title': 'Duolingo: language lessons',
#   'updated': 1692121038,
#   'url': 'https://play.google.com/store/apps/details?id=com.duolingo&hl=en&hl=en&gl=us',
#   'version': None,
#   'video': None,
#   'videoImage': None}]

# %% [markdown]
# ## Retrieving Google Play Reviews

# %% [markdown]
# ## Looping for more Reviews

# %%
start = dt.datetime.now(tz=get_localzone())
fmt= "%m/%d/%y - %T %p"

print('---'*20)
print('---'*20)
print(f'***** {app_name} started at {start.strftime(fmt)}')
print()

app_reviews = []
count = 200
batch_num = 0
# Out:
# ------------------------------------------------------------
# ------------------------------------------------------------
# ***** Duolingo started at 08/17/23 - 13:33:11 PM

# %%
content_list = []
score_list = []

for batch in range(100):
  rvws, token = reviews(
              app_id = 'com.duolingo',
              lang='en',
              country='us',
              sort=Sort.NEWEST,
              count=count,
              continuation_token=token
          )

  for d in rvws:
      if 'content' in d:
        content_list.append(d['content'])

  for s in rvws:
      if 'score' in s:
        score_list.append(d['score'])

  batch_num +=1
  time.sleep(random.randint(1,5))

# %%
pprint(rvws)
# Out:
# [{'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 23, 30),
#   'content': 'Really challenging way to learn a language. I am currently '
#              'learninv napaneese and its going great. Really 😊happy',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'ffd5ab76-128c-4779-8fdc-0b6262f66d00',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSlClrJGNaC4sy4GRWBmHCX7U0l7La0rMHy7dTxaY0eyH0',
#   'userName': 'Johan J Anil'},
#  {'appVersion': '5.114.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 21, 48),
#   'content': '👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍👍',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.3',
#   'reviewId': 'efbedc15-16fd-485d-9d20-7fd54e777d73',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfVlvKWPwh3pw90Jr556sNKaRyjyiCWtM7gxYgb3_na=mo',
#   'userName': 'Tapsi Yadav'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 20, 59),
#   'content': 'I really like the gamification. it works for me',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'a7c7635c-a72e-41dc-b51a-5f96ff55e572',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRbZ54CGh_w6RdrcLduVrcRHOQbyjqxjU7p-f8wgfmToQ',
#   'userName': 'Todd Kappauf'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 18, 19),
#   'content': "So thankful of you. I just have nothing to say. but you're the "
#              'best ever. so helpful',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '79409d02-68dd-48dd-9b65-c3d63c2800d2',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSDa40bORPer4W8RAfL715fZxn9pLY4yq7YmDFGV6Ac6w',
#   'userName': 'Mukasa Brian Bukenya'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 16, 29),
#   'content': "it's. a very nice app I learned my language fast than I thought "
#              'I would I really easy to use and not that much ads the update '
#              "isn't really hard to use than I thought it would be there's not "
#              'really anything bad in this app that I could really think '
#              'of,because this app is good!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '361e5db8-2376-4707-866e-b9865ab1bc25',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdkd5mdF3ny857mm5jVJRupda9uSVRt-PDul2wWvNZG=mo',
#   'userName': 'Aris'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 16, 4),
#   'content': 'Best app ever',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '11a0839a-478d-4eac-ba72-85d148be4628',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQgLroK_O6xK90yl9ZTpyZ-dNp3i1FE2THY8Ba8M6RdbVvi',
#   'userName': 'DADDY and layke Jones'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 15, 43),
#   'content': 'I think its easier to use and effective',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '018f1d6b-9bb3-4456-a6c6-185fd2cdb93b',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdkW5ZE2hAg-pVSr6Ay3kdDALfWmXsly_ISbuDRr3Hl=mo',
#   'userName': 'Nadine Chraycee'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 15, 41),
#   'content': "this app is really fun. I can't stop using it-!",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'a48ac530-a939-48c5-80ae-8b670a99eeb0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS1iHRFKsBpEa3x_kc26LzJiwMsmSWZ3V1a8hsQeFuj8d0',
#   'userName': 'ఌCookie milkఌ'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 14, 36),
#   'content': "it's a good app",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '99e76d8b-67f9-4689-ae8a-001795fd3068',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtctomwSs4ewkP8NIcWYjnLzm2lUJ2HVLFz_s_Cyfnlj=mo',
#   'userName': 'Narendra Lodhi'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 14, 2),
#   'content': 'easy to use, playful, can recommend to ADHD ppl as there is no '
#              'hassle and zillion loops to jump through, you just have to start '
#              'and it is the hardest thing sometimes',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '02476f2e-964a-4ff7-9525-f4305a9870d2',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTTJh1Oc8aMSsuVfLB3fc398qWUsYCiQP_3CkQ0KNJdsoI',
#   'userName': 'Trin Aryss'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 12, 55),
#   'content': 'thank for your help',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'd1d11916-3858-4528-b386-1afb4c2834d5',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdg_ZSdu-KLPs8-2_9bHU8_vz4geoRItnPQn8KzSHHO=mo',
#   'userName': 'Najra Khatoon'},
#  {'appVersion': '5.111.6',
#   'at': datetime.datetime(2023, 8, 12, 13, 11, 47),
#   'content': 'l am happy',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.111.6',
#   'reviewId': '32dc01bd-e24b-4f3e-a725-200ae1bdc211',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfwX-CJ4jhqXr68YtbQjSlxBdV1_krZaU08oOFXFSzE=mo',
#   'userName': 'Aaqib Sir'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 11, 18),
#   'content': 'very very nice 💕💖',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '94f38cb7-6ca3-49c9-80c4-a3f75d22e820',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteGNnWMflzCIoa0AIQhDWGYE3fdkUeoDfd3VKhvnTU=mo',
#   'userName': 'Rambali yadav Rambali yadav'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 9, 30),
#   'content': 'super see schon',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '7bb43136-c1c5-41ec-9b60-31b736428367',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtd4M3zUSLlvh8FOnlMZpFIPtwdAl_fz7ao7MdQDDpsV=mo',
#   'userName': 'Adobor Micheal'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 9, 15),
#   'content': 'this is to good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'dfbeba7f-f188-4d22-8cbe-327901b24ddb',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTterQ5wehOmDup-kP3vos0iu7i0H2ra7q4ijhTP-IFz1=mo',
#   'userName': 'Nusrat Nourin'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 13, 8, 52),
#   'content': 'Very nice app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': 'a8c96fd8-b337-4374-be5d-af2789d4bc9c',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcoJsXDWNT8j-XL3sgNqq02aUHlGRNAx6NaXI3QK-IX=mo',
#   'userName': 'ashraful alam'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 8, 40),
#   'content': 'perfect app to learn any language',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '460d4b4f-4a19-4e9f-9b25-33406068a83f',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT5LNb5n02RGV9cOevYdabflk-8R0-Sxq5bUHGZIE8Bew',
#   'userName': 'Romaisaa Romaisaa Esam'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 8, 13),
#   'content': 'Makes it very easy to learn a new language, and it feels like '
#              "playing a game so it's fun!",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '29aecd76-e0fc-4227-9936-4f4972be12fa',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTrSem0GXxIO3pYYBM2WdWPAiE2hhEvqRKuOq4_ueXpFlw',
#   'userName': 'VALARIE WASWA'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 7, 11),
#   'content': 'nice app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '1e9778f6-8b97-419c-8e6e-a2e93645614d',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTmS1aPUOWDSt98j4upvBO_gnBn_iVj-y_yif0QdDTHYvw',
#   'userName': 'Rajeev Srivastava'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 6, 40),
#   'content': 'this is to good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '17af71c5-3a84-4a1b-bb10-6809e027951b',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdQPyFP8EzeSGNpfBAENh0JUZsfBFXsgh0kvx0ac0Sx=mo',
#   'userName': 'Vaibhav Kumar'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 6, 25),
#   'content': 'Cleverly designed, fun to use.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '835245b8-6856-488a-a64e-690d8ab5b889',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQo2L5u3fcQhrc1fFe-CgY4wimdWMnF6AsrciD_vzMXqcA',
#   'userName': 'K N'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 6, 16),
#   'content': "It's great 😍",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '68453b86-e6c3-4238-bff0-e822ef49bcd3',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTLaaPTJJK7fYtsAkrv9fh6Ev3efo14OLO6kZcwcNbTAKc',
#   'userName': 'Mobina Pazoki'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 5, 54),
#   'content': 'So good love it',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '5b7a5a89-361a-4400-8d87-0ef4f25281ad',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfbSSz6MfWp-_7WexouH946JzltqLRDF-k0A1qIxHSd9A=mo',
#   'userName': 'hasan mujtaba'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 5, 48),
#   'content': 'Even 1% practice a day makes you tougher every day. Thank you '
#              'for the opportunity Duolingo',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '7605e96e-c4ad-4af8-8411-6a3f99217416',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQrrMIiAHrOADEVlj43EZLNHaETDVryWftzEWfy1Z6PUHs',
#   'userName': 'Sayan Ray'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 5, 31),
#   'content': 'is nice',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '1b1ebb66-cf8e-42f7-8934-2caeabdb9feb',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtddNXM6LCzTzl0KqeyWVYTGUwA5o87l6unZFO4pC9Z-=mo',
#   'userName': 'mr emon'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 4, 39),
#   'content': 'awesome. I strongly recommend this app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'e635caa8-28ce-4498-a707-4313a4afd947',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSm1Gw4gLF-qIhG3Ksd5HaEua0PnWqWhbMm59wGQaForA',
#   'userName': 'Manveer Singh'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 4, 27),
#   'content': "It's really a legendary learning app 💯💯💢",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'ff7b2199-d5c9-4723-9a31-4ddbd54f9455',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcy8eQRcjGy3ni67tLcIYhFjJlmk8qw1h0ah_i7F8dm=mo',
#   'userName': 'Shahadat Shahadat'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 4, 25),
#   'content': 'great method!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'e35a4116-a143-482a-a7d5-6815016a6d9d',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfxW3MRlD-PSmnm5q13hitJY-kS7cKmC7EDfAzZ0RGn=mo',
#   'userName': 'Another Me'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 3, 49),
#   'content': 'super',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'e1106304-8378-4183-a749-aa09266f9930',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQZc9rs-J-ejlT9z9FLqWGhPKLIHUvDoL0vhz653gOnaw',
#   'userName': 'ANATHI ANATHI'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 3, 25),
#   'content': 'this app was very nice you all try this',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '1cb273ff-bbf3-46a5-9e05-8eac5ae521e4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcN5cptbOnMsxgbjzsCc9j0f8kL01HQXpiuv13uWn0K=mo',
#   'userName': 'Anil Tiwari'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 3, 20),
#   'content': "It's nice to study language here, hoping for a more game here.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'b537a1c1-9dcd-404a-b2c7-b2daa9979b26',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTIKkrnIhanyCopHF2ECTLGybBau0C1ieD5CqCTPvAYx0Bi',
#   'userName': 'Chris John Catolico'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 13, 1, 49),
#   'content': 'Very good application for learning any language',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'bfe71015-299f-46ad-8b56-b22352b099f7',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfckWkbifog2Swl_rhFezCwL5chZEeJgUbvG9-XwDeZ=mo',
#   'userName': 'Soni Verma'},
#  {'appVersion': '5.112.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 1, 12),
#   'content': 'very nice',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.112.4',
#   'reviewId': '9a2e97f1-703a-4095-9e2f-1f002d9e263b',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRCJRfGHYINDpMN8wyiStySkirw5009qDFoTGQ3Y-dD55GB',
#   'userName': 'Ganesh Gurram'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 13, 1, 11),
#   'content': 'This is a good app and l am so happy',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'f3369912-0f63-4f99-8089-5cf76be31815',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcZ9W2CO8cfK2BDCIWEw0wk1oV2Py0g86M7C68GamQZ=mo',
#   'userName': 'Salim . Rajput'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 59, 51),
#   'content': 'The app is fun and will pester you is not practicing.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '5858101d-b472-4cde-bb03-7dad623df1bf',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtc3yz7p3uTILJhIsPwlD4TnrUXFj05JNo1R1pKR7kSE=mo',
#   'userName': 'David J'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 59, 23),
#   'content': 'Its nice i know now how to speak french eng arabic and more',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': '816c9215-8a29-4918-88d5-6c72eb7a707b',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtd3dx-RpkkksGiBWrhVGlvEIsgATOscl6aWX8XzgjPE=mo',
#   'userName': 'Nour Cell'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 59, 11),
#   'content': 'excellent work',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '97551a08-0308-4f0d-9749-ca4fb0e1b2c2',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTy5ChsW72Kn4gl0q-nap8wnUJnA5L95k16IBlRKKAKh01C',
#   'userName': 'Vikas Mishra'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 58, 22),
#   'content': "it's cute and nice , I really like it very well thank you",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'b2f653b5-6b31-45cd-ac71-6395ddf2a482',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSyNXuuH655yc3iRyO9UajNjDYEcQ3xQIZkZlpfW0-gaRA',
#   'userName': 'Aruna Jithu'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 58, 14),
#   'content': 'good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'f930889c-cfe8-4746-aa43-e2a0427cb955',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfYONV6GTa14Wj05iS7xQLAdFGqaYWXbqul4kjhb5gt=mo',
#   'userName': 'Tabassum Ansari'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 57, 45),
#   'content': 'amazing app I definitely recommend this app if you are trying to '
#              'learn a hard language this app makes it so easy for you',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '67e3ae3c-ee82-4559-b6e2-fb1bee224fdb',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtd_Y5Soksny_KPrDC_Ug3NNV0BLp7-PbAcldYhBGWOK=mo',
#   'userName': 'Fun With Dida'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 57, 18),
#   'content': 'I think Duolingo is the best game it teaches you languages!!!!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '34e6326d-3559-493d-ae62-072f2c9879ad',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtc_PTFsalnmhrSyFQelAL9BSX5TEgjbQxCgt2A2O3mT=mo',
#   'userName': 'semere gebreab'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 57, 6),
#   'content': 'This app is an AMAZING mix of fun and learning. I absolutely '
#              "love that i downloaded Duolingo it's so fun and helpful I'm "
#              'currently learning Swahili and I make sure yo come online '
#              'everyday for my streak so far I have a 67 day streak and you can '
#              'too if you download Duolingo and sometimes depending on how far '
#              'and good you are you might even get THREE FREE DAYS OF SUPER '
#              'DUOLINGO (WHICH IS AMAZING BTW) and you can friend people and '
#              'even make ur own avatar ect 100% RECOMMEND. Have a good day. ♡',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'c2e3372e-36c2-438b-9268-6eaa1b7ca8f0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTgaRBjMjtO5SGjk75tDpIRcEVGEHGGCmBzvW1F9G_j8GI',
#   'userName': 'Gabrielle Browne'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 54, 25),
#   'content': 'this app is very intelligent',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'a287e4d3-6394-4549-a6b3-55ff1e4db061',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteG1WH4vEVLdEh3iV0PDUBMMrJ0uE0ZVts94UMzIo3C=mo',
#   'userName': 'Uniquely Riti'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 52, 5),
#   'content': 'Super app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': '325e7d24-9128-4b6c-80b9-2c539fc31fb2',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTFmuC_s7Dv-f9SPB6R8j6ceALmLCmJiB2F283DBKicng',
#   'userName': 'Pigeon Lover'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 51, 59),
#   'content': 'this good app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '7cf5a36f-db55-4835-9bae-871b252e35db',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcAlC0Ixp_4LMF1z3orGnLuKQMKgf-67tdq7x_aq0q1=mo',
#   'userName': 'HARRYOM SEN'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 51, 39),
#   'content': 'This language learning app is great. I love it 💓.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '730af075-b0c2-4f5a-9216-22504a014d23',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdFVDa8QymPKTXI5x8R_-1N79ZCPK_QXC_jrQkv6Qaw=mo',
#   'userName': 'Ava Universe'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 51, 25),
#   'content': 'I love this app its like game',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': 'fada13d9-4b49-4aaa-a6a7-e77a98560ef9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdIAP8SPQJrCTvrmx1pBLGW1hA7gyyL2VOzEGKb9jM4=mo',
#   'userName': '2ndB,Roll no.2223,Zynah Vanjara'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 51, 17),
#   'content': 'plzz hame reting dey',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '1d2cc191-beaa-44b8-bb76-5d24d489c719',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMREf5-OGOxVy3D0weIoNMEvpQucB77uylSAWE4LVZbbIA',
#   'userName': 'PARAS SANU'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 51, 3),
#   'content': 'It is a best app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '69e47e56-4744-4fa4-84a1-4b97224e66e9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfB4t97bDd4lnw6mfsanNyxfgdpPpOdctGSkr--YvAc=mo',
#   'userName': 'Likesh Sahu'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 50, 56),
#   'content': '👍 Great',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '10eb7569-8d79-402c-8ac8-69a91777b634',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQrA6oLx89UMv0lbq7OUpU5gjgrARkMWNCmi_7tLe1jtbM',
#   'userName': 'Ali Dorali'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 50, 9),
#   'content': "it's a fun and easy way to learn a language. 60 days in and I "
#              'can understand a fair amount of Spanish that will allow me to '
#              'communicate while traveling',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '679fff3d-fa17-487e-b7c7-25e1582f35a5',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTted5C08hK-uxrK0dcmZK9gowEFEBaYMNjxg9Yh2Wo5g=mo',
#   'userName': 'Kimberley Jackson'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 48, 54),
#   'content': 'this is truly fantastic 😊',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'cb107850-69bc-4740-8afe-6aad6db803c5',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSH6-R-0gYnJJ9fCLuKvqFnEnrAD33aoATzinTExcov0Keb',
#   'userName': 'shubham kumar'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 48, 51),
#   'content': 'i studied French for many years when i was younger- five decades '
#              'later it is nice to see havent forgotten everything. Duolingo is '
#              'helping to quickly recover literacy',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '37e74f4a-0b34-408d-880e-e6d52dd65a47',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRR4faNAx6KE4iqPzXVX-aoCb7DLrVEddvRCA_B-lyOQQ',
#   'userName': 'Carol McCreary-Maddox'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 45, 48),
#   'content': 'Mind blowing',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': '1c3caa99-1289-4c9b-b8e0-ee2a948eb218',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdxwv0Q4l_y_zIEOPJSRZbg-9LVdCTUJesg3ieJFf-O=mo',
#   'userName': 'Syed Afzal'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 42, 39),
#   'content': 'nice ये उन\u200c भाईयों के लिए है जो English नहीं जानता है',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'd887c46c-0687-4c38-a667-f305ca0f99ca',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSBugjR8FVKyAy4ELsMcaMtw-Sd-3XbOBhxOTckqj63X3o',
#   'userName': 'Satya deo Suryavanshi jee Modi'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 40, 32),
#   'content': 'very good for learning languages',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '0106856c-6e87-400e-a5e2-a07497ff6013',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTT8sb3aX08CloIJUtQr8PTNf7ZBVqtU51GCYSxWyW0mw',
#   'userName': 'Aneela Imran'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 39, 36),
#   'content': 'very nice 👍👍👍 Duolingo app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'da690be9-73df-4279-876d-e5412a980247',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSGMnNhPghz4VSGYgYmb_6MxKJs43HbLZDlpjTGRB3PRQ',
#   'userName': 'islamic status Fk.'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 38, 30),
#   'content': 'very nice app good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': 'c3a51361-5b94-4525-94da-f30ef0175f31',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRUwFU0qsXixqBHbQllrKJVoxfOxG08mVUBCwQBxPFyWg',
#   'userName': 'Shivam Semwal'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 37, 55),
#   'content': 'great',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '3cef27ea-2e39-4589-a09f-ae9ad12b1862',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRG5VSm7FnXUn4PUcE3qFUpDM0MaqeDhQ45lrEqEeP01w',
#   'userName': 'SHUBHAM POULKAR'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 37, 21),
#   'content': "This app is fun currently I'm learning Japanese",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'ffab4540-ac35-4861-ac16-e041dd657eab',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteO9uutY5nxcNOLDJJeYV72frN4sKU4ATRf6ZAakVV1=mo',
#   'userName': 'Debamita Bhaumik'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 37, 18),
#   'content': "Love this app I'm actually enjoying learning a language (pls "
#              "don't kill my family big green bird) 🥰",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': 'ca44963d-0d86-489c-8387-f8f307c20f47',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSfPv3TxWZ8XY5erqNIZDO_eV_jt9S3dplt_n-VvCaGUw',
#   'userName': 'Lucy Reed'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 37, 11),
#   'content': "I like this aap ,it's teach me like a cute teacher🥰💜",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '16b6940c-2111-4355-a5e0-707fcc971290',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSrVE0vyVj4qvjIutRvg3IdTuEF44Walv0fGgvzgIDJFA',
#   'userName': 'Nandini Tyagi'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 36, 52),
#   'content': 'wish this was around when I was younger. thank you',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '52117eac-8548-4484-bdca-2f50da7194d9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtdpRZixypqWYgwwHAHBACmUXYSMNo7jrBlYtQJ3U7J7=mo',
#   'userName': 'Christen Na'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 34, 24),
#   'content': 'very nice',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '944042d9-f9c5-47e5-9647-1ab0896823eb',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcHd87xp8nEt_lJNV9ZgqBIJHjg0aIQTejEAHL7IDrr=mo',
#   'userName': 'Anbhaw Verma'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 32, 47),
#   'content': 'it is nice and a fun way to learn languages',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '7f9c5432-9c44-4ddc-9e05-e8770476ccff',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSFj6m5v4ifhPg9TJrGxUC5dy9h4XkG1cq0lznWVCQzMsI',
#   'userName': 'Bharat yt'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 32, 12),
#   'content': 'Good app. So convenient and motivating',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '94ee7bfb-15c2-4ab7-9edd-e67a4a1aaf13',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMSLhyvKUXKM9aDQtiIPDXnm0KB50qFe35h_hSISD5mX67U',
#   'userName': 'Артём Андреев'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 30, 39),
#   'content': 'interesting app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '3c038748-19c7-43c6-87d5-1450107e5f56',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfkfExMF6PYV2mya3AaKWxJmzy0bdMHsZb6CZNkd7m4=mo',
#   'userName': 'Samrawit .5'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 30, 38),
#   'content': 'It is very good game because you can learn many languages👄💬 and '
#              'much more. I am learning spanish, French, korean, German, '
#              'Japanese and indian.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '817d41e3-b896-426f-a738-a4eeead8ed21',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtc3-0lrtUun6Idmu4ooGC7MV4S9cI1b0Y6CNUWaQS0N=mo',
#   'userName': 'vidhi khandelwal'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 30, 33),
#   'content': 'I love this app now I Can talk my favorite language',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': 'e9a808eb-2d28-43d0-8a86-81e100435e41',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtebl1VoGiyCkl_Gb4ZQUdlVlTp5S48JgfwpyiT3plKS=mo',
#   'userName': 'Eyael Ermi'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 28, 45),
#   'content': 'my English language trying to a best',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'bdc56c41-b7e2-4e98-849e-88bda3ecbf26',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTYBUJacp9GQJqRAykI9SRljoPSWLmSFszhRkTAx0SuaA',
#   'userName': 'Amin bhai Padarashi'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 28, 22),
#   'content': 'great app!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '15ea8979-f5fc-4566-b73e-5de5b5133f57',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT09dXCjGUV2nFnSJkeF1Znqqke7nVHFKM59EaE0_4y69R2',
#   'userName': 'hank Potter'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 27, 19),
#   'content': "it's bloody good but I find the beginner lessons far too "
#              "repetitive. each to their own, it's not a criticism generally "
#              'speaking duolingo is so good for people who are short on time. '
#              "the morning commute or weekends it's made for it.",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '0cb05d17-c39e-4bc2-ab7c-0781da2eb1b4',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRCeTCki5WmgYGK-o5Nh6qiDr1imSp4-gSe6PUy9DviXw',
#   'userName': 'Iron Mind Video Podcast'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 26, 53),
#   'content': 'really good app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'dbbe5974-dcec-4789-892b-c405364b00f9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMR_-qGRNGoPydAuE-LKk9aHMQVU4xI9YLP7m2EcLlPf18o',
#   'userName': 'Ismail Bantalha'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 24, 51),
#   'content': "I've been using Duolingo for countless years, and I've not seen "
#              'another app like it when it comes to free and diverse language '
#              "learning opportunities. It's great for gaining exposure to the "
#              'sounds and phrases of a language quickly, and increasing the '
#              'vocabulary and grammar rules at an appropriate rate. A must-have '
#              'when it comes to language learning!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '2e58420f-4b6d-42cc-bc70-955eaa1c4e52',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMS2n4CvhKsBW_GmDeRX4aIWDlTCphoNF6OOf9sSm94ABKo',
#   'userName': 'Haydn Chapman'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 24, 24),
#   'content': "I like Duolingo because I'm Irish but I speak English but I'm "
#              "only on a 2 day streak and It's like I know all of irish",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '7b2a36f3-c8c6-4cdf-990b-dc2033fad199',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfNqRqBqF6xV11OBmAOpH7748XnHUUQqbaFTwTr49EO=mo',
#   'userName': 'Thomas Martin'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 22, 12),
#   'content': 'been learning with duo since high school till now i work. really '
#              "helpful. keep on improving & for you that want to start don't "
#              'hesitate to download now. or you just can download now for later '
#              'practice. much love',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '352374bd-a689-4f53-ab68-e41cf473d216',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTDQ4D5Iz1wVKS38M-DzIIuQegVCNbKM9MqpEh-My0RAGM',
#   'userName': 'Elvira Nuraini'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 22, 2),
#   'content': "this app is very good for learning languages and it's good at "
#              'entertainment for language learners too! I find it very nice to '
#              'use this app for my German learning',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '1a97fced-03b2-4bf5-8ba3-d0abb1ca5906',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQLXyx9L3_jEoaUZKlj-Pf6FmWPrEOGU4hrNE2P9j6gWw',
#   'userName': 'Jelp XD'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 21, 25),
#   'content': "amazing app. it's teaching me so much, quickly. easy to "
#              'understand, helpful hints and reminders! Love it!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'f7a75fe7-8d98-4963-aa48-e6c6c85832a0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtd_VK7T0BUdhgtoveqDl6moMwzplMS4ck5kyJHHGw_X=mo',
#   'userName': 'Justin Hill'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 20, 16),
#   'content': 'Love, love, love.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '115c6935-589b-42bf-a54d-88557add0aa2',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte9kjx8RI_sFK7q6Os08xoAujt_6H_z5wwoPh2r8XrZ=mo',
#   'userName': 'MissFloydlover'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 20, 7),
#   'content': 'very nice enjoyjable and smooth enviroment which motivate to '
#              'keep going',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '39f7cd43-8fe6-4a72-9062-97dd20cc1b2b',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTTbdMnPtnG4d4bM6KGjlh7NeHjSY0AaC4AQf-dRC7mEg',
#   'userName': 'Ernesto Medrano'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 19, 21),
#   'content': 'gooooooooood',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '10587079-65d9-41cb-b12d-ac3bd999ebc7',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtf-QVfRn6aXP5kbqFPGkJELScB2mmoUzAyvzPetPKrE=mo',
#   'userName': 'Gopa Mitra'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 18, 24),
#   'content': "it's fantastic",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '7b9b08b8-5231-4a25-9f68-ae560ca63abf',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtevFKNlMhTwscbiLQ284Iy-UGBqCa7RwIWuDxBsL1cn=mo',
#   'userName': 'sam samia'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 16, 44),
#   'content': 'this is a nice app 👌',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'ab24cdd6-2c81-4b4c-88bf-caf35edaf273',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteZdIJw5hoHTAo_6n6AjpZ09aOqOldVlK1GcgzjuTlA=mo',
#   'userName': 'Rehana Khan'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 16, 24),
#   'content': 'nice chote bache ke liye thik hai .. thank you .......',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '06c0ff42-ee76-4340-9d16-b9c3f34a9e07',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMT-W2to6BeUC-VlcUDPyGnCcCHBJWuqpGDjtM57zZPVW6o',
#   'userName': 'Ramesh Kamat'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 15, 51),
#   'content': 'NICE BUT....I WANT SANSKRIT LANGUAGE... THANKYOU',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'c230a455-7207-4b2d-9726-ff9f2771175a',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMReeLM03tg0b5JY55pjLtNGt6IfGnzmJclttHoGkZHSe2E',
#   'userName': 'Koreshu Choudhury'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 14, 27),
#   'content': 'The app is really amazing and really helps you to learn a lot.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '52666da3-877e-4e92-a555-6c7d4dc471e7',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtfYHkht9EXLQdM5Gmy3YkyIlIzGMwNgK_ucC99UnlUJ=mo',
#   'userName': 'Haley Augustus'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 14, 17),
#   'content': 'Very good learning languages app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'b7499cda-9d35-4774-a276-a0ae3b150da0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQFxWPRNPTVFbNKVufRHpT_j0zd6VmBk3ccPcF5Pg-8ZQ',
#   'userName': 'Dante Forde'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 13, 25),
#   'content': 'Duolingo helps me keep my second language sharp and my mind '
#              'LOVES to learn other languages with this system!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '4ca079d8-3823-4afe-a72f-463ea0b6f909',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQm33XGXqu01H7GRke48Cx48QnFeIIa3VptggAkv3oFI9I',
#   'userName': 'Celeste Suiter'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 12, 16),
#   'content': 'this aap is super but English ka stage or jada badhiya jis se '
#              'hum or jada sikhe is me choote words a rahe hai thoda level up '
#              'kariye',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '2f829320-2207-48d2-88b5-276aefe6f33d',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTte5ZGaZyd3kZtKvaCH9zcdoqY4MLMtzwBdlSFMDhwYj=mo',
#   'userName': 'Nishi Ahirwar'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 11, 19),
#   'content': 'Отличное приложение!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'c01896be-46e3-4f42-89d3-5dcb1669df01',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtflBohUoxqLa1KkhtI2kXZXH_UuCa8ugze_JqW_99MYog=mo',
#   'userName': 'Egor Popov'},
#  {'appVersion': '5.99.2',
#   'at': datetime.datetime(2023, 8, 12, 12, 10, 11),
#   'content': 'Easy to learn new languages',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.99.2',
#   'reviewId': 'ca62547d-aca1-428f-a7de-6e28c71e26c0',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcjsFcUMeZwaTZW-neYf8Gb0FIeq28X2kVlAK1AgeIu=mo',
#   'userName': 'P KH'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 9, 24),
#   'content': "that's are very good and nice app",
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': '2baa11f8-0e85-4c0c-84ec-a167df41f6dd',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcmHo7EG_NNMvlkDbGL3ZmOjioFXmukRp235HI6oFRy=mo',
#   'userName': 'Amruta Sankpal'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 8, 15),
#   'content': 'Excellent learning tool, even in free mode.',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': 'ffe121f3-7744-4209-950b-7550a19fdb7d',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMTwqcnm3EKew_7DpgPCO4NxaWAchlpvWyKyUMvrkNsBMw',
#   'userName': 'Dean Sole'},
#  {'appVersion': '5.114.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 7, 44),
#   'content': 'Duolingo is the best app',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.114.4',
#   'reviewId': 'd39dc96b-3a0d-4d6f-a3c8-28b062349c81',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtcjQl6boXvBbhCpchRGUTeZM4YWHMudM4DANYJL6rGW=mo',
#   'userName': 'Sangeeta Gupta'},
#  {'appVersion': None,
#   'at': datetime.datetime(2023, 8, 12, 12, 7, 35),
#   'content': 'nice',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': None,
#   'reviewId': 'd2ff7ae7-4813-49cc-8c09-e41b6bfa530f',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMRx1rK9cpG-2qfEzRDneuy6B_liCfItZJHA2QQnOrfB-K0',
#   'userName': 'Behzod'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 7, 28),
#   'content': 'very good knowledgeable app for learning English',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '953d10f5-e3ac-40ba-a0ea-cb2cf8220ef9',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteMEwB0HotYvf7XKixUx8Y1QNLOKkSM2_JF7rYfONUz=mo',
#   'userName': 'VANDANA SANOTHIYA'},
#  {'appVersion': '5.113.3',
#   'at': datetime.datetime(2023, 8, 12, 12, 6, 21),
#   'content': 'Best',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.113.3',
#   'reviewId': '6bd17b7b-aaaf-46dd-929d-9c84db26bcf1',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTteGKGuxaw4T4NITqwQm-8UbFCirH5JFbW3qoPVXIIr6=mo',
#   'userName': 'Joseph Femi'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 6, 12),
#   'content': 'I like it a lot it feels so good to get a perfect in a lesson!',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '2f3ae1db-f396-49df-a171-2b39eb0b3c7c',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQEElyE-mLr1zrf_abaFpfdeJ0vIXSmIB7NH7FGjUF3ew',
#   'userName': 'Topher Coyle'},
#  {'appVersion': '5.65.12',
#   'at': datetime.datetime(2023, 8, 12, 12, 2, 47),
#   'content': 'Good',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.65.12',
#   'reviewId': 'a8a5ee6c-3b2f-46cc-b136-8a3f80a3ad2d',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a-/AD_cMMQYykV0ul9TWDzgQLSBEorpneKXGsdnHDWKHJKiclR1Rkc',
#   'userName': 'md naimur rahaman'},
#  {'appVersion': '5.115.4',
#   'at': datetime.datetime(2023, 8, 12, 12, 2, 38),
#   'content': "I'm really enjoying the app. I was able to do it for a month "
#              'then stopped and started again. everytime I learn new words I '
#              'think "I\'m never going to remember this" but then when I look '
#              'again I can think on my feet. definitely recommend it',
#   'repliedAt': None,
#   'replyContent': None,
#   'reviewCreatedVersion': '5.115.4',
#   'reviewId': '2b33571a-c347-4520-acb0-00f5876858f3',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'userImage': 'https://play-lh.googleusercontent.com/a/AAcHTtedh-grQy4Cmm8LEC-My3m7Djy0KVBxnV2Z_ySlyix8=mo',
#   'userName': 'Esli Kekana'}]

# %%
df = pd.DataFrame({'id': range(1, len(content_list) + 1), 'review': content_list, 'score': score_list})
df.head()
# Out:
#    id                                             review  score
# 0   1                                   it's pretty good      5
# 1   2            the app is great for learning languages      5
# 2   3  This is my fav app and i love this app In this...      5
# 3   4                                           love it.      5
# 4   5  It's very fun to play we can pronounce write v...      5

# %%
df.shape
# Out:
# (5000, 3)

# %% [markdown]
# ## Sentiment Analysis

# %%
import numpy as np
pd.options.mode.chained_assignment = None

from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin

from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB

import re
import nltk
from nltk import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from collections import Counter

nltk.download('vader_lexicon')

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Splitting Data into training and validation sets

# %%
train_df, val_df = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# Defining Function to Pre-Process the Reviews

# %%
class ReviewPreprocessor(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X_transformed = X.copy()

        for col in X.columns:
            X_transformed[col] = X_transformed[col].astype(str).apply(lambda text: text.lower())
            X_transformed[col] = X_transformed[col].apply(lambda text: re.sub(r'[^A-Za-z0-9 ]+', ' ', text))

        return X_transformed

# %%
preprocessing_pipeline = Pipeline([
    ('text_preprocessor', ReviewPreprocessor())
])

# %%
train_df = preprocessing_pipeline.transform(train_df)
val_df = preprocessing_pipeline.transform(val_df)

train_df.head()
# Out:
#         id                                             review score
# 4227  4228                                   great experience     5
# 4676  4677  ma sha allah this app is really amazing it hel...     5
# 800    801  just getting started  day 2  it is going reall...     5
# 3671  3672                                               best     5
# 4193  4194                 very good way to learn i love this     5

# %% [markdown]
# Analyzing Reviews by Predicting Sentiments

# %%
sia = SentimentIntensityAnalyzer()

def get_sentiment_score(text):
    sentiment_score = sia.polarity_scores(text)
    if sentiment_score['compound'] >= 0.05:
        return 'positive'
    elif sentiment_score['compound'] <= -0.05:
        return 'negative'
    else:
        return 'neutral'

def get_sentiment_score_specific(text):
    sentiment_score = sia.polarity_scores(text)
    if sentiment_score['compound'] >= 0.05:
        return sentiment_score['compound']
    elif sentiment_score['compound'] <= -0.05:
        return sentiment_score['compound']
    else:
        return sentiment_score['compound']


train_df['sentiment'] = train_df['review'].apply(get_sentiment_score)
train_df['sentiment_score'] = train_df['review'].apply(get_sentiment_score_specific)

# %%
sentiment_counts = train_df['sentiment'].value_counts()

print(sentiment_counts)
# Out:
# positive    3361
# neutral      592
# negative      47
# Name: sentiment, dtype: int64

# %%
score_counts = train_df['score'].value_counts()

print(score_counts)
# Out:
# 5    4000
# Name: score, dtype: int64

# %%
train_df.head(20)
# Out:
#         id                                             review score sentiment  \
# 4227  4228                                   great experience     5  positive
# 4676  4677  ma sha allah this app is really amazing it hel...     5  positive
# 800    801  just getting started  day 2  it is going reall...     5  positive
# 3671  3672                                               best     5  positive
# 4193  4194                 very good way to learn i love this     5  positive
# 2968  2969                        nice enviroment like a game     5  positive
# 4793  4794  the best  it feels mandatory to learn and to p...     5  positive
# 4368  4369              makes language learning easy and fun      5  positive
# 2776  2777  very good app i like it this very useful this app     5  positive
# 2970  2971  i now know how to tell people that i eat cats ...     5   neutral
# 3867  3868  this app is amazing i like it  it thought my j...     5  positive
# 1743  1744  i love this game so much  it teach me  it s so...     5  positive
# 3948  3949                           very very nice app           5  positive
# 3802  3803                                          so good       5  positive
# 2024  2025                                      amazing app       5  positive
# 2274  2275  currently  i am learning french and the lesson...     5  positive
# 99     100                                               good     5  positive
# 4921  4922                                       it s great       5  positive
# 3407  3408                                          excellent     5  positive
# 4245  4246  i like these duolingo game because these game ...     5  positive
#
#       sentiment_score
# 4227           0.6249
# 4676           0.7939
# 800            0.7818
# 3671           0.6369
# 4193           0.8122
# 2968           0.6486
# 4793           0.8807
# 4368           0.7351
# 2776           0.8462
# 2970           0.0000
# 3867           0.7430
# 1743           0.8307
# 3948           0.5222
# 3802           0.4927
# 2024           0.5859
# 2274           0.4019
# 99             0.4404
# 4921           0.6249
# 3407           0.5719
# 4245           0.3612

# %%
negative_rows = train_df[train_df['sentiment'] == 'negative']
negative_rows
# Out:
#         id  \
# 2495  2496
# 3322  3323
# 356    357
# 452    453
# 2304  2305
# 3231  3232
# 3869  3870
# 557    558
# 3011  3012
# 2955  2956
# 1498  1499
# 479    480
# 976    977
# 4641  4642
# 1019  1020
# 4467  4468
# 2476  2477
# 739    740
# 448    449
# 3880  3881
# 421    422
# 1725  1726
# 4329  4330
# 3741  3742
# 4813  4814
# 1092  1093
# 1579  1580
# 4272  4273
# 696    697
# 4017  4018
# 2248  2249
# 1772  1773
# 4039  4040
# 1111  1112
# 3090  3091
# 3701  3702
# 2713  2714
# 3850  3851
# 2958  2959
# 4206  4207
# 3086  3087
# 918    919
# 3031  3032
# 4134  4135
# 713    714
# 4725  4726
# 1528  1529
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   review  \
# 2495                                                                                                                                                                                                                                                                                                                                                                                                                                                         it s good but the ads is so annoying   and it s like a game
# 3322                                                                                                                                                                                                                                                                                                                                                                                                                          good app but i lost my streak of 16 weeks today and i can t find my mom dad and sister now
# 356                                                                                                                                                                                                                                                                                                                                                                                                                                               the app does not open i have struggled since yesterday  what is wrong
# 452                                                                                                                                                                                                                                                                                                                                                     it s very nice for learning different languages  the first time i heard about it i didn t too much about it but after some time i don t regret downloading it
# 2304                                                                                                                                                                                                                                                                                                                                                                     this is an excellent app for learning all areas of french but they have begun to use loud and annoying ads  which i think cheapens their brand
# 3231                                                                                                                                                                                                                                                                                                                                                                                                                                                           green bird is pointing a gun to my head  i had no choice
# 3869                                                                                                                                                                                                                                                                                                                                                                                                  extremely practical app  uses repetitive questions to memorize all words and pointing your mistakes to learn more
# 557                                                                                                                                                                                                                                                                                                                                                                                                                                                 the killer owl memes made me start but learning german made me stay
# 3011                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             you can t stop learning
# 2955                                                                                                                                                                                                                                                                                                                                                                          i am learning spanish  so it s working  i now know how to ask for an apple  which has been a problem in the past  whoops i meant  manzana
# 1498                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         it s very low level english
# 479                                                                                                                                                                                                                                                                                   this is a great app  as you see  i m improving my english a lot  but sometimes  if you don t write exactly the way duo writes  we lose a     i understand that and o don t blame duo but i think he should give some more options
# 976                                                                                                                                                                                                                                                                                                                                                                                                                                                app is to good but there is not sanskrit language please add sanskrit
# 4641                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               obsessed with duo tbh
# 1019                                                                                                                                                                                                                                                                                                                                                                                       perfect but  for example  in french that i am learning  some sounds are not clear  and why duo doesn t have farsi to english
# 4467                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            very good  no complaints
# 2476                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          the internet is very poor
# 739                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      muy buena app  no tengo quejas
# 448                                                                                                                                                                                                                                                                                                                                                                                                                               they made learning spanish a game  and if you re competitive enough  you can t say no
# 3880                                                                                                                                                                                                                                                                                                                                                   i have a love hate relationship with duo  but i have stuck with it for over 1300 days  twice daily now  argh but it does force me to practice  and i am learning
# 421                                                                                                                                                                                                                                                                                                                                                                    sometimes the app is a little glitchy so i have to restart it  i have also lost lessons  too  so i lose the points accrues  otherwise  great app
# 1725                                                                                                                                                                                                                                                                                                                                                                                                                      they didn t kidnap me or my family even though i missed my spanish  german  and finish lessons
# 4329                                            apparently  if you use the app on your computer  you don t have to worry about losing stars  which is somewhat irritating  since when you run out  you have to practice to earn more and continue moving through the program  it is a good program to learn from  but i admit  i m not starting from scratch  i am trying to re learn from my high school and college days  i haven t tried to start a program with no prior knowledge  so i can t speak to that aspect
# 3741                                                                                                                                                                                                                                                                                                                                                                                                                                                             this app is very good  but the  ads  are very annoying
# 4813                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 but hotmas that pay
# 1092                                                                                                                                                                                                                                                                                                                                                                                                                                                                              the duolingo is not winner on type now
# 1579                                                                                                                                                                                                                                                                                                                                                                      ich sch tze diesen app wirklich  habe schon viel gelernt und ist mir eine gro e hilfe  mit die landessprache sprache mehr bekannt zu werden
# 4272                                                                                                                                                                                                                                                                                                                                                                                                               this app taught me many languages but the duolingo but duolingo bird broke my parents legs at 3 00 am
# 696                                                                                                                                                                                                                                                                                                                                                                                                                                                   first they hated tea innit  and then paul said he had a boyfriend
# 4017                                                                                                                                                                                                                                                                                                                                                                                      the owl is very demanding and only a tiny bit terrifying  it s best to just do what he says and practice your language skills
# 2248                                                                                                                                                                                                                                                                                                                                                                                                                        i gave you a 5 stars review so please don t kill me for just missing your lesson for a week
# 1772                                                                                                                                                                                                                                                                                                                                                                                                                                                                          great game but some times i find it boring
# 4039                                                                                                                                                                                                                                                                                          i can learn any language with this app it will observe and make you practice everyday if you don t practice it will teach you the same thing and what you mistakes it will make you to do the exercises at the last moment
# 1111                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           no worries about language
# 3090                                                                                                                                                                                                              very good app  the gameified nature makes learning a language more fun  my complaints include the fact that a lot of languages have smaller courses due to being less popular  which is sad but i understand it  i also dislike when duo steals my family  but it keeps me on my streak  so it s okay
# 3701                                                                                                                                                                                                                                                                                                                                                                                                                                                                                this is a world  s no 1 learning app
# 2713  i ve absolutely no complain after the recent update  it s been almost 2 years of me using duolingo to learn japanese the only complaint i had was that kanji was neglected quite a bit it was a hassle to learn kanji  i was jumping from apps to apps exploring websites to get a hold of kanji  but now i ve finally got a section whole heartedly dedicated to kanji in duo  god i am legit crying  u guys have no idea how much this means to me it may seem dramatic but people trust me kanji really f u up
# 3850                                                                                                                                                                                                                                                                                                                                                                                                                                                                yah sab to theek hai per aur hard hard sawal puchiye
# 2958                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      5 stars no explanation needed
# 4206                                                                                                                                                                                                                                                                                                                                         i liked the widgit while it lasted on my android  but the latest update killed it  now  i see i would have to download another app  which is not compatible with my device
# 3086                                                                                                                                                                                                                                                                              bring back the profile photo  spanish course  one pair of four in the pronunciation task always has no audio  make word blocks movable  upvotes downvotes in comments aren t save  hide the native language from selectable languages
# 918                                                                                                                                                                                                                                                                                                                                                                 really good app  only problem is that when you get 5 questions wrong  you have to wait for 4 hours to get th back unless you have gems or pay for it
# 3031                                                                                                                                                                                                                                                                                                                                                                                                                                                                        disappointed that nobody replies to messages
# 4134                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    app no problem
# 713                                           duolingo bardzo mi pomaga  mozna szybko i  atwo si  du o nauczy  ja jestem na poziomie takim  e ci zko porozumiewa  sie z kims po angieslku w normalnym  yciu  wsesie ze nie ustawione slowka itp w szkole  a ta apka mi mega pomaga  jest duzo zach t do nauki np po 6 7 dniom graniu podrz d mozna ustawic sobie s wke na ekran  jest duzo nagrod jak i tracemke zyc  mozna ke potem odzyskac  z super duolingo nie ma reklam i duze u atwienie graczom  bardzo polecam
# 4725                                                                                                                                                                                                                                                                                                              i guess the best compared to falou and drops  but idunno it s my opinion also i m learning to speak spanish if you come by this message  i rlly need spanish friends so bad you can email me or idunno
# 1528                                                                                                                                                                                                                                                                                                                                                                                                                          this is one of the most authentic app which provide the poor who is live far from the city
#
#      score sentiment  sentiment_score
# 2495     5  negative          -0.1373
# 3322     5  negative          -0.2500
# 356      5  negative          -0.2649
# 452      5  negative          -0.3926
# 2304     5  negative          -0.2960
# 3231     5  negative          -0.5574
# 3869     5  negative          -0.5423
# 557      5  negative          -0.3919
# 3011     5  negative          -0.2960
# 2955     5  negative          -0.4019
# 1498     5  negative          -0.3384
# 479      5  negative          -0.4939
# 976      5  negative          -0.1263
# 4641     5  negative          -0.1779
# 1019     5  negative          -0.1093
# 4467     5  negative          -0.3069
# 2476     5  negative          -0.5256
# 739      5  negative          -0.2960
# 448      5  negative          -0.1280
# 3880     5  negative          -0.3071
# 421      5  negative          -0.1757
# 1725     5  negative          -0.2960
# 4329     5  negative          -0.5029
# 3741     5  negative          -0.4391
# 4813     5  negative          -0.1531
# 1092     5  negative          -0.4717
# 1579     5  negative          -0.5994
# 4272     5  negative          -0.5719
# 696      5  negative          -0.6369
# 4017     5  negative          -0.1761
# 2248     5  negative          -0.6337
# 1772     5  negative          -0.1027
# 4039     5  negative          -0.3612
# 1111     5  negative          -0.6124
# 3090     5  negative          -0.6082
# 3701     5  negative          -0.2960
# 2713     5  negative          -0.1840
# 3850     5  negative          -0.2023
# 2958     5  negative          -0.2960
# 4206     5  negative          -0.7469
# 3086     5  negative          -0.1531
# 918      5  negative          -0.4601
# 3031     5  negative          -0.4767
# 4134     5  negative          -0.5994
# 713      5  negative          -0.2263
# 4725     5  negative          -0.1247
# 1528     5  negative          -0.4767

# %% [markdown]
# ## Exploring Results

# %%
pd.set_option('max_colwidth', 1000)

ultra_positive = train_df[(train_df['sentiment'] == 'positive') & (train_df['sentiment_score'] > 0.9)]
ultra_positive.head()
# Out:
#         id  \
# 2264  2265
# 3017  3018
# 1215  1216
# 3997  3998
# 432    433
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                review  \
# 2264                                                                                                                                                                                                                                                            i very much like how you got to learn language for free  i appreciate the continuous upgrade the developer and his team  keep up the good works  thank you for being people closer by offering free language lessons
# 3017   this is a very good learning app  i m learning spanish but sometimes some words a southern american  rarely  i have difficulty remembering and being motivated to actually do a lesson so i make sure to keep notifications on  i also think sometimes i find the legendary levels to be a bit hard since they always give you words and you only have to rearrange them  affing to the difficulty could be beneficial  overall its helped me learn more spanish for my family
# 1215                                                                                                                                                                                                                                                                                                                                                                                          i love this app i have really learned alot in my desired language and it s easy and fun
# 3997                                                                                                                                                                                                                                                                                                                     it  s really great  even better than a language class  you can learn languages free  it  s really fun  if you don t practice  duolingo will send you emails
# 432   duolingo provides a lot of practice repetition of vocabulary as well as allows you to practice listening  reading  writing  and speaking skills  there are some fun games you can play to master vocabulary and grammar  you can also compete with fellow students and move through leagues from week to week  there is a point and rewards system to keep you interested  i would recommend keeping notes to refer to from the grammar notes and or daily practices  have fun
#
#      score sentiment  sentiment_score
# 2264     5  positive           0.9475
# 3017     5  positive           0.9503
# 1215     5  positive           0.9100
# 3997     5  positive           0.9377
# 432      5  positive           0.9545

# %%
ultra_negative = train_df[(train_df['sentiment'] == 'negative') & (train_df['sentiment_score'] < -0.5)]
ultra_negative.head()
# Out:
#         id  \
# 3231  3232
# 3869  3870
# 2476  2477
# 4329  4330
# 1579  1580
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         review  \
# 3231                                                                                                                                                                                                                                                                                                                                                                                                                 green bird is pointing a gun to my head  i had no choice
# 3869                                                                                                                                                                                                                                                                                                                                                        extremely practical app  uses repetitive questions to memorize all words and pointing your mistakes to learn more
# 2476                                                                                                                                                                                                                                                                                                                                                                                                                                                the internet is very poor
# 4329  apparently  if you use the app on your computer  you don t have to worry about losing stars  which is somewhat irritating  since when you run out  you have to practice to earn more and continue moving through the program  it is a good program to learn from  but i admit  i m not starting from scratch  i am trying to re learn from my high school and college days  i haven t tried to start a program with no prior knowledge  so i can t speak to that aspect
# 1579                                                                                                                                                                                                                                                                                                                            ich sch tze diesen app wirklich  habe schon viel gelernt und ist mir eine gro e hilfe  mit die landessprache sprache mehr bekannt zu werden
#
#      score sentiment  sentiment_score
# 3231     5  negative          -0.5574
# 3869     5  negative          -0.5423
# 2476     5  negative          -0.5256
# 4329     5  negative          -0.5029
# 1579     5  negative          -0.5994

# %%
average_lengths = train_df.groupby('sentiment')['review'].apply(lambda x: x.str.len().mean()).reset_index()

average_lengths.columns = ['sentiment', 'average_review_length']
print(average_lengths)
# Out:
#   sentiment  average_review_length
# 0  negative             119.234043
# 1   neutral              25.869932
# 2  positive              56.905385

# %% [markdown]
# Most common negative words

# %%
negative_reviews = train_df[train_df['sentiment'] == 'negative']['review']

stop_words = set(stopwords.words('english'))
all_words = [word.lower() for review in negative_reviews for word in nltk.word_tokenize(review) if word.isalnum() and word.lower() not in stop_words]

most_common_words = Counter(all_words).most_common(10)

print(most_common_words)
